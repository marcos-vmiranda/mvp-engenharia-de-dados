# %% [markdown]
# ## Descrição
# Esse notebook realiza a importação de arquivos CSV do bucket S3 para um volume gerenciado no Databricks, utilizando comandos para copiar os dados do armazenamento externo para o ambiente controlado do Unity Catalog. Isso prepara os dados para análise e processamento nas etapas seguintes do pipeline.

# %%
# %sql
USE CATALOG mvp;
USE SCHEMA staging;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS volume01;

# %%
# %sql
SHOW VOLUMES
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>volume_name</th></tr></thead><tbody><tr><td>staging</td><td>volume01</td></tr></tbody></table></div>

# %%
# Importa os arquivos do S3 para o volume
dbutils.fs.cp("s3a://pos-puc-mvp/ind-prod-ilha.csv", "dbfs:/Volumes/mvp/staging/volume01/ind-prod-ilha.csv")
dbutils.fs.cp("s3a://pos-puc-mvp/bases.csv", "dbfs:/Volumes/mvp/staging/volume01/bases.csv")
dbutils.fs.cp("s3a://pos-puc-mvp/ilhas.csv", "dbfs:/Volumes/mvp/staging/volume01/ilhas.csv")
# Out:
# True
