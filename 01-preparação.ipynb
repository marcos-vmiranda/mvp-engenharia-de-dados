# %% [markdown]
# ## Descrição
# Esse notebook executa comandos SQL para criar o catálogo e os schemas necessários no workspace do Databricks. Ele garante que a estrutura básica de dados (catálogo e schema) esteja pronta para as próximas etapas do pipeline, permitindo o armazenamento e organização dos dados.

# %%
# %sql
DROP CATALOG IF EXISTS mvp CASCADE

# %%
# %sql
CREATE CATALOG mvp

# %%
# %sql
USE CATALOG mvp

# %%
# %sql
DROP SCHEMA IF EXISTS staging CASCADE

# %%
# %sql
CREATE SCHEMA staging

# %%
# %sql
DROP SCHEMA IF EXISTS bronze CASCADE

# %%
# %sql
CREATE SCHEMA bronze

# %%
# %sql
DROP SCHEMA IF EXISTS silver CASCADE

# %%
# %sql
CREATE SCHEMA silver

# %%
# %sql
DROP SCHEMA IF EXISTS gold CASCADE

# %%
# %sql
CREATE SCHEMA gold
